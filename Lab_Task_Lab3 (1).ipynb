# %% [markdown]
# # Import Libraries

# %%
import numpy as np
from skimage import io, color, exposure, img_as_float
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1

# %%
# Load the "land.jpeg" image
I = io.imread("/content/land.jpeg")
# Normalize the image using img_as_float
I = img_as_float(I)

# Calculate the histogram
hist, bins = exposure.histogram(I.ravel(), nbins=256)

# Calculate the cumulative histogram
chist, cbins = exposure.cumulative_distribution(I.ravel(), nbins=256)

# In a 1 by 3 subplots
plt.rcParams['figure.figsize'] = (8, 10)
plt.subplot(1, 3, 1)
io.imshow(I)
plt.axis("off")
plt.title("image")

plt.subplot(1, 3, 2)
plt.plot(bins, hist, 'k')
plt.xlabel("pixel values")
plt.title("histogram")

plt.subplot(1, 3, 3)
plt.plot(cbins, chist, 'r', lw=3)
plt.ylabel("percentage")
plt.title("cumulative histogram")

plt.show()
# Out:
# <ipython-input-20-2bb465664780>:15: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)

# %% [markdown]
# # Task 2

# %%
# Perform global histogram equalization on the image
I_histeq = exposure.equalize_hist(I)
hist_I_histeq, bins_I_histeq = exposure.histogram(I_histeq.ravel(), nbins=256)

# Perform adaptive histogram equalization (AHE) with kernel size = (41, 41)
I_ahe = exposure.equalize_adapthist(I, kernel_size=(41, 41))
hist_I_ahe, bins_I_ahe = exposure.histogram(I_ahe.ravel(), nbins=256)

# Perform CLAHE with kernel size = (41, 41) and clip limit = 0.05
I_clahe = exposure.equalize_adapthist(I, kernel_size=(41, 41), clip_limit=0.05)
hist_I_clahe, bins_I_clahe = exposure.histogram(I_clahe.ravel(), nbins=256)

# %%
# In a 2 by 4 subplots (plt.subplots(1, 3, ...)), show the followings:
#    I           I_histeq           I_ahe          I_clahe
# hist(I)     hist(I_histeq)     hist(I_ahe)    hist(I_clahe)

plt.rcParams['figure.figsize'] = (18,6)
plt.subplot(2, 4, 1)
io.imshow(I)
plt.axis("off")
plt.title("I")

plt.subplot(2, 4, 2)
io.imshow(I_histeq )
plt.axis("off")
plt.title("I_histeq")

plt.subplot(2, 4, 3)
io.imshow(I_ahe )
plt.axis("off")
plt.title("I_ahe")

plt.subplot(2, 4, 4)
io.imshow(I_clahe)
plt.axis("off")
plt.title("I_clahe")

plt.subplot(2, 4, 5)
plt.plot(bins, hist, 'k')
plt.xlabel("pixel values")
plt.title("hist(I)")

plt.subplot(2, 4,6)
plt.plot(bins_I_histeq,hist_I_histeq , 'k')
plt.xlabel("pixel values")
plt.title("hist(I_histeq) ")

plt.subplot(2, 4, 7)
plt.plot(bins_I_ahe ,hist_I_ahe, 'k')
plt.xlabel("pixel values")
plt.title("hist(I_ahe) ")

plt.subplot(2, 4, 8)
plt.plot(bins_I_clahe,hist_I_clahe, 'k')
plt.xlabel("pixel values")
plt.title("hist(I_clahe)")
# Out:
# <ipython-input-22-063f9b5d36ed>:7: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)
# <ipython-input-22-063f9b5d36ed>:12: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I_histeq )
# <ipython-input-22-063f9b5d36ed>:17: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I_ahe )
# <ipython-input-22-063f9b5d36ed>:22: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I_clahe)
# Text(0.5, 1.0, 'hist(I_clahe)')
